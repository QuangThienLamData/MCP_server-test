# %%
import requests
from urllib.parse import urlencode
from dotenv import load_dotenv
import os

# %%
load_dotenv()
API_KEY = os.getenv("API_KEY")

endpoint = "top-headlines"

parameters = {
    "category": "technology",
    "lang": "en",
    "country": "us",
    "max": 5,
    "apikey": API_KEY
}

query_string = urlencode(parameters)

url = f"https://gnews.io/api/v4/{endpoint}?{query_string}"

# Make the GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    print(data)  # The JSON response from the API
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# {'information': {'realTimeArticles': {'message': 'Real-time news data is only available on paid plans. Free plan has a 12-hour delay. Upgrade your plan here to remove the delay: https://gnews.io/change-plan'}}, 'totalArticles': 168250, 'articles': [{'id': 'd66d724584bf223d792922cecb6242cd', 'title': "Capcom Spotlight Announced For This Week, Here's A Teaser Trailer", 'description': 'Expect "roughly 30-minutes" of news and updates - It\'s been an action-packed year for Capcom so far, and it\'s got even more on the way. Following a bunch of ...', 'content': 'Capcom is on a massive roll these past couple of years. And its not just for one console, or two, but they are pumping out blockbuster games for everything they put their hands on. My biggest surprise in that teaser was seeing MHS3. Really hoping thi... [661 chars]', 'url': 'https://www.nintendolife.com/news/2026/06/capcom-spotlight-announced-for-this-week-heres-a-teaser-trailer', 'image': 'https://images.nintendolife.com/3540981b5
# ...

# %%
#import pprint
#pprint.pprint(data)

for article in data["articles"]:
    print(article["title"])
    print(article["description"])
    print(article["url"])
    print()
# Out:
# Capcom Spotlight Announced For This Week, Here's A Teaser Trailer
# Expect "roughly 30-minutes" of news and updates - It's been an action-packed year for Capcom so far, and it's got even more on the way. Following a bunch of ...
# https://www.nintendolife.com/news/2026/06/capcom-spotlight-announced-for-this-week-heres-a-teaser-trailer
#
# Capcom Spotlight set for June 25
# Capcom will host a Capcom Spotlight broadcast on June 25 at 2:00 p.m. PT / 5:00 p.m. ET / June 27 at 7:00 JST, the company announced. You will be able to watch…
# https://www.gematsu.com/2026/06/capcom-spotlight-set-for-june-25
#
# Prime Day deals are officially live: Shop the best tech sales from Apple, Sony, Bose, Anker and others for up to 54% off right now
# Prime Day deals have discounted a bunch of our favorite tech from headphones to TVs to iPhone accessories and more.
# ...

# %%
# load_dotenv()
# API_KEY = os.getenv("API_KEY")

# endpoint = "top-headlines"

parameters = {
    "page": 2,
    "per_page": 50
}

query_string = urlencode(parameters)

url = f"https://api.discogs.com/artists/1/releases?{query_string}"

# Make the GET request
response = requests.get(url)

# Check if the request was successful
if response.status_code == 200:
    data = response.json()
    print(data)  # The JSON response from the API
else:
    print(f"Error: {response.status_code}")
    print(response.text)
# Out:
# {'pagination': {'page': 2, 'pages': 3, 'per_page': 50, 'items': 130, 'urls': {'first': 'https://api.discogs.com/artists/1/releases?page=1&per_page=50', 'last': 'https://api.discogs.com/artists/1/releases?page=3&per_page=50', 'prev': 'https://api.discogs.com/artists/1/releases?page=1&per_page=50', 'next': 'https://api.discogs.com/artists/1/releases?page=3&per_page=50'}}, 'releases': [{'id': 27077919, 'status': 'Accepted', 'type': 'release', 'format': '2xFile, MP3, EP, 320', 'label': 'CMND CTRL', 'title': 'CTRL008', 'resource_url': 'https://api.discogs.com/releases/27077919', 'role': 'Remix', 'artist': 'B. Riley*', 'trackinfo': 'Within Dreams (The Per...', 'year': 2022, 'thumb': '', 'stats': {'community': {'in_wantlist': 2, 'in_collection': 1}}}, {'id': 28493269, 'status': 'Accepted', 'type': 'release', 'format': '12", EP', 'label': 'Kwench Records', 'title': 'E.T.Ascension EP', 'resource_url': 'https://api.discogs.com/releases/28493269', 'role': 'Remix', 'artist': 'Cassy', 'trackinfo'
# ...

# %%
#import pprint
#pprint.pprint(data)

for page in data["releases"]:
    print(page["title"])
    print(page["artist"])
    print(page["year"])
    print()
# Out:
# CTRL008
# B. Riley*
# 2022
#
# E.T.Ascension EP
# Cassy
# 2023
#
# Untitled
# Brommage Dub
# 1997
#
# Untitled
# Brommage Dub
# 1997
#
# Sun Trip - Fifth
# Various
# 1998
#
# Goldhead Music Sampler Vol 2 1997
# Various
# 1997
#
# Live @ The Traxx
# Ian Pooley
# 1997
#
# The Lords Of Svek Vol. 2
# Various
# 1997
#
# The Lords Of Svek Vol. 4
# Various
# 1998
#
# The Lords Of Svek Vol. 3
# Various
# 1998
#
# hr3 Clubnight Volume 3
# Mark Spoon
# 1998
#
# Le Nord Digital - Volume 2
# Various
# 1998
#
# DeeperDimensions
# Felver*
# 1998
#
#  How To Chill
# DJ Tres Manos*
# 1998
#
# A Night On The Town
# Kenneth Graham
# 1998
#
# Fresh Produce
# Jesse Brooks
# 1998
#
# That Smarts!
# Miles Maeda
# 1998
#
# The Lords Of Svek - Unreleased
# Various
# 1998
#
# Boréalis
# Various
# 1998
#
# Jérôme Pacman's House Café
# Jérôme Pacman
# 1998
#
# DJ Excursions Vol 5
# Simon Caldwell & Ken Cloud
# 1998
#
# Groove (The Compilation Volume 3)
# Various
# 1998
#
# The Lords Of Svek - Galaxy
# Various
# ...
